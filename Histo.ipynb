# %%
import pandas as pd
from matplotlib import pyplot as plt


# Layout1 = pd.read_csv('Results/Hist_layout1.csv', sep=';')
Layout2 = pd.read_csv('Results/Hist_layout2.csv', sep=';')
Layout3 = pd.read_csv('Results/Hist_layout3.csv', sep=';')



# plt.hist(Layout1['Distributed'], bins=10, edgecolor='black')
# plt.xlabel('Sum of cost')
# plt.ylabel('Frequency')
# plt.title('Distributed')

# plt.hist(Layout1['CBS'], bins=10, edgecolor='black')
# plt.xlabel('Sum of cost')
# plt.ylabel('Frequency')
# plt.title('CBS')

plt.hist(Layout1['Prioritized'], bins=10, edgecolor='black')
plt.xlabel('Sum of cost')
plt.ylabel('Frequency')
plt.title('Prioritized')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/woutersouge/Documents/LR Master/AE4422 - Agent Based/AE4422/Results/Histo.ipynb Cell 1 in <cell line: 6>()
#       <a href='vscode-notebook-cell:/Users/woutersouge/Documents/LR%20Master/AE4422%20-%20Agent%20Based/AE4422/Results/Histo.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> from matplotlib import pyplot as plt
#       <a href='vscode-notebook-cell:/Users/woutersouge/Documents/LR%20Master/AE4422%20-%20Agent%20Based/AE4422/Results/Histo.ipynb#W0sZmlsZQ%3D%3D?line=4'>5</a> # Layout1 = pd.read_csv('Results/Hist_layout1.csv', sep=';')
# ----> <a href='vscode-notebook-cell:/Users/woutersouge/Documents/LR%20Master/AE4422%20-%20Agent%20Based/AE4422/Results/Histo.ipynb#W0sZmlsZQ%3D%3D?line=5'>6</a> Layout2 = pd.read_csv('Results/Hist_layout2.csv', sep=';')
# ...

# %%
fig, ax = plt.subplots()
Layout1.plot.kde(ax=ax, legend=True, title='Distributed vs. Prioritized vs. CBS')
Layout1.plot.hist(density=True, ax=ax, alpha = 0.5)
ax.set_ylabel('Probability')
ax.set_xlabel('Sum of cost')
ax.grid(axis='y')
